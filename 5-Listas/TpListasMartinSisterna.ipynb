# %% [markdown]
# 1) Crear una lista con los números del 1 al 100 que sean múltiplos de 4. Utilizar la función range.

# %%
multiplos_de_4 = list(range(4, 101, 4))
print(multiplos_de_4)

# %% [markdown]
# 2) Crear una lista con cinco elementos (colocar los elementos que más te gusten) y mostrar el penúltimo. ¡Puedes hacerlo como se muestra en los videos o bien investigar cómo funciona el indexing con números negativos!

# %%
multi4 = ["Danonino", 77, "Gustavo", "Keanu ", "Reeves"]

print(multi4[3])

# %% [markdown]
# 3) Crear una lista vacía, agregar tres palabras con append e imprimir la lista resultante por pantalla. Pista: para crear una lista vacía debes colocar los corchetes sin nada en su interior. Por ejemplo:

# %%
lista_vacia = []

lista_vacia.append("Popeye")
lista_vacia.append("Pocoyo")
lista_vacia.append("Pepe Argento")

print(lista_vacia)

# %% [markdown]
# 4) Reemplazar el segundo y último valor de la lista “animales” con las palabras “loro” y “oso”, respectivamente. Imprimir la lista resultante por pantalla. ¡Puedes hacerlo como se muestra en los videos o bien investigar cómo funciona el indexing con números negativos!

# %%
animales = ["perro", "gato", "conejo", "pez"]

animales[1] = "loro"
animales[3] = "oso"

print(animales)

# %% [markdown]
# 5) Analizar el siguiente programa y explicar con tus palabras qué es lo que realiza.

# %%
numeros = [8, 15, 3, 22, 7]
numeros.remove(max(numeros))
print(numeros)

# %% [markdown]
# El operador remove() eliminó al numero maximo de la lista por otro operador max() 22 es el numero mas alto asi que remove(max(numeros)) elimina al 22 que seria el numero mas alto de la lista

# %% [markdown]
# 6) Crear una lista con números del 10 al 30 (incluído), haciendo saltos de 5 en 5 y mostrar por pantalla los dos primeros.

# %%
saltos = list(range(10, 31, 5))

print(saltos[0],saltos[1]) # los dos primeros sin incluir el 30
print(saltos[0],saltos[1],saltos[2],saltos[4]) # los dos primeros entre el 10 y el 30

# %% [markdown]
#  7) Reemplazar los dos valores centrales (índices 1 y 2) de la lista “autos” por dos nuevos valores cualesquiera.

# %%
autos = ["sedan", "polo", "suran", "gol"]

autos[1] = input("Ingrese algun valor para el indice[1]: ")
autos[2] = input("Ingrese algun valor para el indice[2]: ")

print(autos)

# %% [markdown]
# 8) Crear una lista vacía llamada "dobles" y agregar el doble de 5, 10 y 15 usando append directamente. Imprimir la lista resultante por pantalla.

# %%
dobles = []

dobles.append(5**2)
dobles.append(10**2)
dobles.append(15**2)

print(dobles)

# %% [markdown]
# 9) Dada la lista “compras”, cuyos elementos representan los productos comprados pordiferentes clientes:

# %%
compras = [["pan", "leche"], ["arroz", "fideos", "salsa"],["agua"]]

print(compras)  

compras[2].append("jugo")
compras[1][1] = ("tallarines")
compras[0].remove("pan")

print(compras)

# %% [markdown]
# 10) Elaborar una lista anidada llamada “lista_anidada” que contenga los siguientes elementos:
# ● Posición lista_anidada[0]: 15
# ● Posición lista_anidada[1]: True
# ● Posición lista_anidada[2][0]: 25.5
# ● Posición lista_anidada[2][1]: 57.9
# ● Posición lista_anidada[2][2]: 30.6
# ● Posición lista_anidada[3]: False
# Imprimir la lista resultante por pantalla.

# %%
Lista_anidada = [15, True, [25.5, 57.9, 30.6], False]
print(Lista_anidada)
